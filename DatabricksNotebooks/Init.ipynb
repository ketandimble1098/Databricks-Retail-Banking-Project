-- %%
USE CATALOG databricks_ws_dev

-- %%
-- CREATE SCHEMA IF NOT EXISTS silver;
-- CREATE SCHEMA IF NOT EXISTS gold;

-- %%
-- GRANT ALL PRIVILEGES ON SCHEMA silver TO `pra@gmail.com`;
-- GRANT ALL PRIVILEGES ON SCHEMA gold TO `pra@gmail.com`;

-- %%
CREATE TABLE silver.dim_account
USING DELTA
LOCATION 'abfss://silver@sabankingkd.dfs.core.windows.net/account/';
